# %% [markdown]
# <a href="https://colab.research.google.com/github/gurliv21/deforestation-domain-adaptation/blob/main/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gurliv21/deforestation-domain-adaptation.git
# Out:
# Cloning into 'deforestation-domain-adaptation'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
